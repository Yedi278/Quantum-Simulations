# %%
from qiskit import __version__
assert __version__ >= '2.0.0', f"Required Qiskit 2.0.0 or later, but you have {__version__}."

from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, transpile
from qiskit.visualization import plot_histogram

# %%
qr = QuantumRegister(2, 'q')

qc = QuantumCircuit(qr)

qc.initialize([0, 1], qr[0])
qc.initialize([1, 0], qr[1])

qc.h(qr[0])
qc.cx(qr[0], qr[1])

qc.measure_all()
qc.draw('mpl')

# %%
# density_matrix
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 # density_matrix
# ----> 3 density_matrix = qc.to_density_matrix()
#
# AttributeError: 'QuantumCircuit' object has no attribute 'to_density_matrix'
